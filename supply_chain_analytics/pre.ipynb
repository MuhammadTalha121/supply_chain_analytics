# %%
import pandas as pd

# %%
df = pd.read_csv('Lloyds_Bank_Larger_Customer_Churn_Dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df = pd.read_csv('Lloyds_Bank_Larger_Customer_Churn_Dataset.csv')
#
# File c:\Users\HP\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import numpy as np

X = np.array([22, 34, 12, 45, 32, 21, 42, 12])
y = np.array([222, 333, 122, 434, 353, 231, 490, 99])

b = 0
w = 10


y_hat = b + w * X

mse = (y_hat - y) ** 2
print(y_hat)
print(y)
print(mse)
# Out:
# [220 340 120 450 320 210 420 120]
# [222 333 122 434 353 231 490  99]
# [   4   49    4  256 1089  441 4900  441]

# %%
import matplotlib.pyplot as plt

plt.plot(y_hat, color='red')
plt.plot(y_hat, mse)

# %%
X_sum = sum(X)
y_sum = sum(y)
x_y = X * y
X_y_sum = sum(x_y)
X_sum_square = np.sum(X ** 2)

n = len(X)

numerator_n = (n*X_y_sum) - (X_sum * y_sum)
denominator_n = (n*X_sum_square) - (X_sum**2)

slope_m = numerator_n/denominator_n

mean_X = X_sum / n
mean_y = y_sum / n

intercept_b = mean_y - (slope_m * mean_X)

y_hat2 = slope_m * X + intercept_b
print(y)
print(y_hat2)
MSE = (y_hat2 - y)
print(np.mean(MSE))
# Out:
# [222 333 122 434 353 231 490  99]
# [225.71422261 356.15591873 117.01280919 475.7274735  334.41563604
#  214.84408127 443.11704947 117.01280919]
# -1.0658141036401503e-14

# %%
plt.plot(y, color='red')
plt.plot(y_hat2, color='black')
